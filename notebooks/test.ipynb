# %%
import pandas as pd

# %%
data = {
    'apple':[2,3,4,5,6],
    'oranges': [8,4,7,5,4],
    'banana': [4,5,6,7,8]
}

# %%
data
# Out:
# {'apple': [2, 3, 4, 5, 6],
#  'oranges': [8, 4, 7, 5, 4],
#  'banana': [4, 5, 6, 7, 8]}

# %%
print(data)
# Out:
# {'apple': [2, 3, 4, 5, 6], 'oranges': [8, 4, 7, 5, 4], 'banana': [4, 5, 6, 7, 8]}

# %%
fruits = pd.DataFrame(data)

# %%
fruits
# Out:
#    apple  oranges  banana
# 0      2        8       4
# 1      3        4       5
# 2      4        7       6
# 3      5        5       7
# 4      6        4       8

# %%
print(fruits)
# Out:
#    apple  oranges  banana
# 0      2        8       4
# 1      3        4       5
# 2      4        7       6
# 3      5        5       7
# 4      6        4       8

# %%
purchases = pd.DataFrame(data, index = ['Jan', 'Rob', 'Lily', 'Dave', 'Kany'])

# %%
purchases
# Out:
#       apple  oranges  banana
# Jan       2        8       4
# Rob       3        4       5
# Lily      4        7       6
# Dave      5        5       7
# Kany      6        4       8

# %%
purchases.loc['Rob']
# Out:
# apple      3
# oranges    4
# banana     5
# Name: Rob, dtype: int64

# %%
df = pd.read_csv(r'C:\Users\REISD5\Downloads\Cashflow - January 26.csv')

# %%
df
# Out:
#     Unnamed: 0        Unnamed: 1       Unnamed: 2 Unnamed: 3  Unnamed: 4  \
# 0          NaN               NaN          January        NaN         NaN
# 1          NaN               NaN              NaN        NaN         NaN
# 2          NaN          Overview              NaN        NaN         NaN
# 3          NaN               NaN              NaN        NaN         NaN
# 4          NaN  Cash Flow Actual         positive        NaN         NaN
# 5          NaN  Cash Flow Budget         negative        NaN         NaN
# 6          NaN     Spending Rate           54,20%        NaN         NaN
# 7          NaN   Largest Expense  Gitarre + Setup        NaN         NaN
# 8          NaN               NaN              NaN        NaN         NaN
# 9          NaN          Cashflow              NaN        NaN         NaN
# 10         NaN               NaN              NaN        NaN         NaN
# 11         NaN          Category           Budget     Actual         NaN
# ...

# %%
df = pd.read_csv(r'C:\Users\REISD5\Downloads\Cashflow - January 26.csv', index_col=0)

# %%
df
# Out:
#            Unnamed: 1       Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# NaN               NaN          January        NaN         NaN        NaN
# NaN               NaN              NaN        NaN         NaN        NaN
# NaN          Overview              NaN        NaN         NaN        NaN
# NaN               NaN              NaN        NaN         NaN        NaN
# NaN  Cash Flow Actual         positive        NaN         NaN        NaN
# NaN  Cash Flow Budget         negative        NaN         NaN        NaN
# NaN     Spending Rate           54,20%        NaN         NaN        NaN
# NaN   Largest Expense  Gitarre + Setup        NaN         NaN        NaN
# NaN               NaN              NaN        NaN         NaN        NaN
# NaN          Cashflow              NaN        NaN         NaN      Bills
# NaN               NaN              NaN        NaN         NaN        NaN
# NaN          Category           Budget     Actual         NaN   Category
# ...

# %%
import json

# %%
df.head()
# Out:
#            Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# NaN               NaN    January        NaN         NaN        NaN        NaN
# NaN               NaN        NaN        NaN         NaN        NaN        NaN
# NaN          Overview        NaN        NaN         NaN        NaN        NaN
# NaN               NaN        NaN        NaN         NaN        NaN        NaN
# NaN  Cash Flow Actual   positive        NaN         NaN        NaN        NaN
#
#      Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# NaN         NaN        NaN        NaN          NaN         NaN         NaN
# NaN         NaN        NaN        NaN          NaN         NaN         NaN
# NaN         NaN        NaN        NaN          NaN         NaN         NaN
# NaN         NaN        NaN        NaN          NaN         NaN         NaN
# NaN         NaN        NaN        NaN          NaN         NaN         NaN
#
# ...

# %%
df.tail()
# Out:
#       Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# NaN          Car      80,00       0,00         NaN        NaN        NaN
# NaN         Gold       0,00       0,00         NaN        NaN        NaN
# NaN     Vacation       0,00       0,00         NaN        NaN        NaN
# NaN  Equate Plus       0,00       0,00         NaN        NaN        NaN
# NaN        Total     230,00     150,00         NaN      Total      45,00
#
#      Unnamed: 7       Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11  \
# NaN         NaN    Backfischfest       0,00          NaN         NaN
# NaN         NaN       Kfz Steuer       0,00          NaN         NaN
# NaN         NaN  Gitarre + Setup     362,00          NaN         NaN
# NaN         NaN          Kreatin       0,00          NaN         NaN
# NaN         NaN            Total     555,00          NaN       Total
#
#     Unnamed: 12 Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# ...

# %%
df.tail(2)
# Out:
#       Unnamed: 1 Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# NaN  Equate Plus       0,00       0,00         NaN        NaN        NaN
# NaN        Total     230,00     150,00         NaN      Total      45,00
#
#      Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# NaN         NaN    Kreatin       0,00          NaN         NaN         NaN
# NaN         NaN      Total     555,00          NaN       Total      330,00
#
#     Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16 Unnamed: 17 Unnamed: 18
# NaN         NaN          NaN          NaN          NaN         NaN         NaN
# NaN       30,00          NaN          NaN          NaN         NaN         NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 38 entries, nan to nan
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 1   30 non-null     str
#  1   Unnamed: 2   26 non-null     str
#  2   Unnamed: 3   21 non-null     str
#  3   Unnamed: 4   0 non-null      float64
#  4   Unnamed: 5   9 non-null      str
#  5   Unnamed: 6   8 non-null      str
#  6   Unnamed: 7   0 non-null      float64
#  7   Unnamed: 8   28 non-null     str
#  8   Unnamed: 9   27 non-null     str
#  9   Unnamed: 10  0 non-null      float64
#  10  Unnamed: 11  7 non-null      str
#  11  Unnamed: 12  6 non-null      str
#  12  Unnamed: 13  6 non-null      str
#  13  Unnamed: 14  0 non-null      float64
#  14  Unnamed: 15  0 non-null      float64
#  15  Unnamed: 16  0 non-null      float64
#  16  Unnamed: 17  12 non-null     str
#  17  Unnamed: 18  12 non-null     str
# dtypes: float64(6), str(12)
# memory usage: 5.6 KB

# %%
df.shape
# Out:
# (38, 18)

# %%
temp_df = pd.concat([df, df])

# %%
temp_df.shape
# Out:
# (76, 18)

# %%
temp_df = temp_df.drop_duplicates()

# %%
temp_df.shape
# Out:
# (35, 18)

# %%
df.shape
# Out:
# (38, 18)

# %%
df_new = df.drop_duplicates()

# %%
df_new.shape
# Out:
# (35, 18)

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18'],
#       dtype='str')

# %%
df.rename(columns={'Unnamed: 1': 'Test'}, inplace=True)

# %%
df.head()
# Out:
#                  Test Unnamed: 2 Unnamed: 3  Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# NaN               NaN    January        NaN         NaN        NaN        NaN
# NaN               NaN        NaN        NaN         NaN        NaN        NaN
# NaN          Overview        NaN        NaN         NaN        NaN        NaN
# NaN  Cash Flow Actual   positive        NaN         NaN        NaN        NaN
# NaN  Cash Flow Budget   negative        NaN         NaN        NaN        NaN
#
#      Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# NaN         NaN        NaN        NaN          NaN         NaN         NaN
# NaN         NaN        NaN        NaN          NaN         NaN         NaN
# NaN         NaN        NaN        NaN          NaN         NaN         NaN
# NaN         NaN        NaN        NaN          NaN         NaN         NaN
# NaN         NaN        NaN        NaN          NaN         NaN         NaN
#
# ...

# %%
df.columns = ['Test', 'Unna2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
       'Unnamed: 6', 'Unnamed: 7', 'Ued: 8', 'Unnamed: 9', 'Unnamed: 10',
       'Unnamed: 11', 'Uned: 12', 'amed: 13', 'Unnamed: 14',
       'Unnamed: 15', 'Unnamed: 16', 'Umed: 17', 'Unnamed: 18']

# %%
df.head()
# Out:
#                  Test     Unna2 Unnamed: 3  Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# NaN               NaN   January        NaN         NaN        NaN        NaN
# NaN               NaN       NaN        NaN         NaN        NaN        NaN
# NaN          Overview       NaN        NaN         NaN        NaN        NaN
# NaN  Cash Flow Actual  positive        NaN         NaN        NaN        NaN
# NaN  Cash Flow Budget  negative        NaN         NaN        NaN        NaN
#
#      Unnamed: 7 Ued: 8 Unnamed: 9  Unnamed: 10 Unnamed: 11 Uned: 12 amed: 13  \
# NaN         NaN    NaN        NaN          NaN         NaN      NaN      NaN
# NaN         NaN    NaN        NaN          NaN         NaN      NaN      NaN
# NaN         NaN    NaN        NaN          NaN         NaN      NaN      NaN
# NaN         NaN    NaN        NaN          NaN         NaN      NaN      NaN
# NaN         NaN    NaN        NaN          NaN         NaN      NaN      NaN
#
# ...

# %%
df.columns = [col.lower() for col in df]

# %%
df.head()
# Out:
#                  test     unna2 unnamed: 3  unnamed: 4 unnamed: 5 unnamed: 6  \
# NaN               NaN   January        NaN         NaN        NaN        NaN
# NaN               NaN       NaN        NaN         NaN        NaN        NaN
# NaN          Overview       NaN        NaN         NaN        NaN        NaN
# NaN  Cash Flow Actual  positive        NaN         NaN        NaN        NaN
# NaN  Cash Flow Budget  negative        NaN         NaN        NaN        NaN
#
#      unnamed: 7 ued: 8 unnamed: 9  unnamed: 10 unnamed: 11 uned: 12 amed: 13  \
# NaN         NaN    NaN        NaN          NaN         NaN      NaN      NaN
# NaN         NaN    NaN        NaN          NaN         NaN      NaN      NaN
# NaN         NaN    NaN        NaN          NaN         NaN      NaN      NaN
# NaN         NaN    NaN        NaN          NaN         NaN      NaN      NaN
# NaN         NaN    NaN        NaN          NaN         NaN      NaN      NaN
#
# ...

# %%
df.head(3)
# Out:
#          test    unna2 unnamed: 3  unnamed: 4 unnamed: 5 unnamed: 6  \
# NaN       NaN  January        NaN         NaN        NaN        NaN
# NaN       NaN      NaN        NaN         NaN        NaN        NaN
# NaN  Overview      NaN        NaN         NaN        NaN        NaN
#
#      unnamed: 7 ued: 8 unnamed: 9  unnamed: 10 unnamed: 11 uned: 12 amed: 13  \
# NaN         NaN    NaN        NaN          NaN         NaN      NaN      NaN
# NaN         NaN    NaN        NaN          NaN         NaN      NaN      NaN
# NaN         NaN    NaN        NaN          NaN         NaN      NaN      NaN
#
#      unnamed: 14  unnamed: 15  unnamed: 16 umed: 17 unnamed: 18
# NaN          NaN          NaN          NaN      NaN         NaN
# NaN          NaN          NaN          NaN      NaN         NaN
# NaN          NaN          NaN          NaN      NaN         NaN

# %%
df.isnull()
# Out:
#       test  unna2  unnamed: 3  unnamed: 4  unnamed: 5  unnamed: 6  unnamed: 7  \
# NaN   True  False        True        True        True        True        True
# NaN   True   True        True        True        True        True        True
# NaN  False   True        True        True        True        True        True
# NaN  False  False        True        True        True        True        True
# NaN  False  False        True        True        True        True        True
# NaN  False  False        True        True        True        True        True
# NaN  False  False        True        True        True        True        True
# NaN  False   True        True        True       False        True        True
# NaN  False  False       False        True       False       False        True
# NaN  False  False       False        True       False       False        True
# NaN  False  False       False        True       False       False        True
# ...

# %%
df.isnull().sum()
# Out:
# test            5
# unna2           9
# unnamed: 3     14
# unnamed: 4     35
# unnamed: 5     26
# unnamed: 6     27
# unnamed: 7     35
# ued: 8          7
# unnamed: 9      8
# unnamed: 10    35
# unnamed: 11    28
# uned: 12       29
# amed: 13       29
# unnamed: 14    35
# unnamed: 15    35
# unnamed: 16    35
# umed: 17       23
# unnamed: 18    23
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df['unnamed: 4'].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: unnamed: 4, dtype: float64

# %%
df.corr()
# Out:
#              test  unna2  unnamed: 3  unnamed: 4  unnamed: 5  unnamed: 6  \
# test          NaN    NaN         NaN         NaN         NaN         NaN
# unna2         NaN    NaN         NaN         NaN         NaN         NaN
# unnamed: 3    NaN    NaN         NaN         NaN         NaN         NaN
# unnamed: 4    NaN    NaN         NaN         NaN         NaN         NaN
# unnamed: 5    NaN    NaN         NaN         NaN         NaN         NaN
# unnamed: 6    NaN    NaN         NaN         NaN         NaN         NaN
# unnamed: 7    NaN    NaN         NaN         NaN         NaN         NaN
# ued: 8        NaN    NaN         NaN         NaN         NaN         NaN
# unnamed: 9    NaN    NaN         NaN         NaN         NaN         NaN
# unnamed: 10   NaN    NaN         NaN         NaN         NaN         NaN
# unnamed: 11   NaN    NaN         NaN         NaN         NaN         NaN
# uned: 12      NaN    NaN         NaN         NaN         NaN         NaN
# ...
